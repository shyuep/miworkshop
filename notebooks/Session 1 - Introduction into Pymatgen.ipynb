# %% [markdown]
# # Introduction
#
# In this session, we will be using pymatgen to get data from the Materials Project, and perform some analysis.

# %%
from pymatgen.ext.matproj import MPRester

# %%
mpr = MPRester()

# %%
mpr.get_structures("LiFePO4")
# Out:
# [Structure Summary
#  Lattice
#      abc : 8.485696817244845 7.4001835800000002 14.845161545212123
#   angles : 90.0 90.9580366148477 90.0
#   volume : 932.08220760746292
#        A : 8.4854911099999999 0.0 -0.059085499999999999
#        B : 0.0 7.4001835800000002 0.0
#        C : -0.14485508 0.0 14.844454799999999
#  PeriodicSite: Li (0.5070, 4.9485, 6.0452) [0.0667, 0.6687, 0.4075]
#  PeriodicSite: Li (0.5573, 6.0839, 11.2561) [0.0786, 0.8221, 0.7586]
#  PeriodicSite: Li (0.8061, 4.9912, 1.1856) [0.0964, 0.6745, 0.0803]
#  PeriodicSite: Li (3.3643, 1.2911, 6.2071) [0.4036, 0.1745, 0.4197]
#  PeriodicSite: Li (3.4682, 2.3839, 10.9811) [0.4214, 0.3221, 0.7414]
#  PeriodicSite: Li (3.6633, 1.2484, 1.3475) [0.4333, 0.1687, 0.0925]
#  PeriodicSite: Li (4.6773, 6.1518, 13.4379) [0.5667, 0.8313, 0.9075]
#  PeriodicSite: Li (4.8725, 5.0163, 3.8043) [0.5786, 0.6779, 0.2586]
#  PeriodicSite: Li (4.9764, 6.1091, 8.5783) [0.5964, 0.8255, 0.5803]
# ...
